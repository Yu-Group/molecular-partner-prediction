# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings("ignore")
from os.path import join as oj
import numpy as np
import viz
from style import *
import analyze_helper

outcome_def = 'y_consec_thresh'
out_dir = oj('/scratch/users/vision/abc', 'apr28_1')
results = analyze_helper.load_results(out_dir)

# %% [markdown]
# **baseline stats**

# %%
viz.print_metadata(acc=results.accuracy.max())
# Out:
# valid:		2066 aux+ / 7594 (0.272)
# ----------------------------------------
# hotspots:	 349 aux+ /  349
# short:		 212 aux+ / 4266 (0.950)
# long:		  41 aux+ /   43 (0.953)
# hard:		1482 aux+ / 2936 (0.505)
# ----------------------------------------
# hard acc:			  0.760
# total acc (no hotspots):	  0.873

# %% [markdown]
# **look at prediction metrics**

# %%
r = results
r = r[[k for k in r if not 'std' in k]]
r = r[[k for k in r if not '_f' in k]]
# r = r[r.index.str.contains('ros')] # only use random sampling
r = r.sort_values(by=['accuracy', 'balanced_accuracy'], ascending=False).head(100)
# r.style.background_gradient(cmap='viridis', axis=None) # all values on same cmap
r.style.background_gradient(cmap='viridis', axis=0) # columns differently colored
# r.style.apply(viz.highlight_max, subset=[k for k in r if not 'std' in k])
# Out:
# <style  type="text/css" >
#     #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow0_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow0_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow0_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow0_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow0_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow0_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow1_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow1_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow1_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow1_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow1_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow1_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow2_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow2_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow2_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow2_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow2_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow2_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow3_col0 {
#             background-color:  #25ab82;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow3_col1 {
#             background-color:  #25ab82;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow3_col2 {
#             background-color:  #24aa83;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow3_col3 {
#             background-color:  #1f9e89;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow3_col4 {
#             background-color:  #1e9b8a;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow3_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow4_col0 {
#             background-color:  #25ab82;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow4_col1 {
#             background-color:  #25ab82;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow4_col2 {
#             background-color:  #24aa83;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow4_col3 {
#             background-color:  #1f9e89;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow4_col4 {
#             background-color:  #1e9b8a;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow4_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow5_col0 {
#             background-color:  #25ab82;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow5_col1 {
#             background-color:  #25ab82;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow5_col2 {
#             background-color:  #24aa83;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow5_col3 {
#             background-color:  #1f9e89;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow5_col4 {
#             background-color:  #1e9b8a;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow5_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow6_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow6_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow6_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow6_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow6_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow6_col5 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow7_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow7_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow7_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow7_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow7_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow7_col5 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow8_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow8_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow8_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow8_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow8_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8e872c5e_89b2_11ea_98a4_002590e83e0arow8_col5 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }</style><table id="T_8e872c5e_89b2_11ea_98a4_002590e83e0a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >accuracy</th>        <th class="col_heading level0 col1" >balanced_accuracy</th>        <th class="col_heading level0 col2" >f1</th>        <th class="col_heading level0 col3" >precision</th>        <th class="col_heading level0 col4" >recall</th>        <th class="col_heading level0 col5" >roc_auc</th>    </tr>    <tr>        <th class="index_name level0" >model_type</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>

# %% [markdown]
# **look at feat importances**

# %%
r = results
# r.style.apply(viz.highlight_max, subset=[k for k in r if not 'std' in k])
# r = r[r.accuracy > np.percentile(r.accuracy, 80)]

keys = [k for k in r if '_f' in k]
keys_remapped = {k: k.replace('_f', '') for k in keys}
r = r[keys].rename(columns=keys_remapped)
# r = r.sort_values('lifetime')
r = r.rename(columns={'mean_square_displacement': 'msd', 'total_displacement': 'td'})
# r = r[r2.index.str.contains('ros')]
# r = r[r.index.str.contains('none')]
r = r[[k for k in r if not 'std' in k]]


def rank(r):
    '''Rank feature importances appropriately
    '''
    r = r.abs()
    r = r.rank(axis=1, ascending=False, method='min')
    return r
# 
r = rank(r)
# r = r.reindex(r.mean().sort_values(ascending=True).index, axis=1) # sort cols by mean rank

idxs = r.index
r.insert(0, 'acc', results.loc[idxs]['accuracy'])
r = r.sort_values('acc', ascending=False)
r = r.reindex(r.iloc[0].sort_values(ascending=True).index, axis=1) # sort cols by mean rank
subset = list(r.keys())
subset.remove('acc')
r.insert(1, 'num_feats', r.apply(lambda row: np.sum(~np.isnan(row.values)) - 1, axis=1))


def color_vals(val):
    colors = {
        1: cb, 2: cp, 3: cr,
    }
    if not val in colors:
        color = 'maroon'
    else:
        color = colors[val]
    return 'color: %s' % color

# r = r[r.num_feats <= 5].head(10)

r.fillna("").style.applymap(color_vals, subset=subset)
# r.fillna(0).style.background_gradient(cmap='viridis_r', axis=1, subset=subset) # rows differently colored
