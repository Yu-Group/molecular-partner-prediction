# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import warnings
import sys
sys.path.append('../src')
warnings.filterwarnings("ignore")
from os.path import join as oj
import numpy as np
import viz
from viz import *
import analyze_helper

outcome_def = 'y_consec_thresh'
out_dir = oj('/scratch/users/vision/abc', 'may7_1')
# out_dir = oj('/scratch/users/vision/abc', 'aug19_binary1')
results = analyze_helper.load_results(out_dir)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# **baseline stats**

# %%
viz.print_metadata(acc=results.accuracy.max())
# Out:
# valid:		2066 aux+ / 7594 (0.272)
# ----------------------------------------
# hotspots:	 349 aux+ /  349
# short:		 283 aux+ / 5697 (0.950)
# long:		 108 aux+ /  113 (0.953)
# hard:		1482 aux+ / 2936 (0.505)
# ----------------------------------------
# hard acc:			  0.760
#
# lifetime threshes 15 161

# %% [markdown]
# **look at prediction metrics**

# %%
r = results
r = r[[k for k in r if not 'std' in k]]
r = r[[k for k in r if not '_f' in k]]
# r = r[r.index.str.contains('ros')] # only use random sampling
r = r.sort_values(by=['accuracy', 'balanced_accuracy'], ascending=False).head(100)
# r.style.background_gradient(cmap='viridis', axis=None) # all values on same cmap
r.style.background_gradient(cmap='viridis', axis=0) # columns differently colored
# r.style.apply(viz.highlight_max, subset=[k for k in r if not 'std' in k])

# %% [markdown]
# **look at feat importances**

# %%
r = results
# r.style.apply(viz.highlight_max, subset=[k for k in r if not 'std' in k])
# r = r[r.accuracy > np.percentile(r.accuracy, 80)]

keys = [k for k in r if '_f' in k]
keys_remapped = {k: k.replace('_f', '') for k in keys}
r = r[keys].rename(columns=keys_remapped)
# r = r.sort_values('lifetime')
r = r.rename(columns={'mean_square_displacement': 'msd', 'total_displacement': 'td'})
# r = r[r2.index.str.contains('ros')]
# r = r[r.index.str.contains('none')]
r = r[[k for k in r if not 'std' in k]]


def rank(r):
    '''Rank feature importances appropriately
    '''
    r = r.abs()
    r = r.rank(axis=1, ascending=False, method='min')
    return r
# 
r = rank(r)
# r = r.reindex(r.mean().sort_values(ascending=True).index, axis=1) # sort cols by mean rank

idxs = r.index
r.insert(0, 'acc', results.loc[idxs]['accuracy'])
r = r.sort_values('acc', ascending=False)
r = r.reindex(r.iloc[0].sort_values(ascending=True).index, axis=1) # sort cols by mean rank
subset = list(r.keys())
subset.remove('acc')
r.insert(1, 'num_feats', r.apply(lambda row: np.sum(~np.isnan(row.values)) - 1, axis=1))


def color_vals(val):
    colors = {
        1: cb, 2: cp, 3: cr,
    }
    if not val in colors:
        color = 'maroon'
    else:
        color = colors[val]
    return 'color: %s' % color

r = r[r.num_feats < 7].head(10)

r.fillna("").style.applymap(color_vals, subset=subset)
# r.fillna(0).style.background_gradient(cmap='viridis_r', axis=1, subset=subset) # rows differently colored
# Out:
# <style  type="text/css" >
#     #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col2 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col3 {
#             color:  #cc3399;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col4 {
#             color:  #cc0000;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col5 {
#             color:  #1f77b4;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col6 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col7 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col8 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col9 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col10 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col11 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col12 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col13 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow0_col14 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col2 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col3 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col4 {
#             color:  #cc0000;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col5 {
#             color:  #1f77b4;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col6 {
#             color:  #cc3399;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col7 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col8 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col9 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col10 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col11 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col12 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col13 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow1_col14 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col2 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col3 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col4 {
#             color:  #cc3399;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col5 {
#             color:  #1f77b4;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col6 {
#             color:  #cc0000;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col7 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col8 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col9 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col10 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col11 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col12 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col13 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow2_col14 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col2 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col3 {
#             color:  #cc3399;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col4 {
#             color:  #cc0000;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col5 {
#             color:  #1f77b4;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col6 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col7 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col8 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col9 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col10 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col11 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col12 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col13 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow3_col14 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col2 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col3 {
#             color:  #cc3399;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col4 {
#             color:  #cc0000;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col5 {
#             color:  #1f77b4;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col6 {
#             color:  #cc0000;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col7 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col8 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col9 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col10 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col11 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col12 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col13 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow4_col14 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col2 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col3 {
#             color:  #cc3399;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col4 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col5 {
#             color:  #1f77b4;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col6 {
#             color:  #cc0000;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col7 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col8 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col9 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col10 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col11 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col12 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col13 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow5_col14 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow6_col2 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow6_col3 {
#             color:  #cc3399;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow6_col4 {
#             color:  #cc0000;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow6_col5 {
#             color:  #1f77b4;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow6_col6 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow6_col7 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow6_col8 {
#             color:  maroon;
#         }    #T_d1403969_e264_11ea_8a0b_002590e83e0arow6_col9 {
#             color:  maroon;
#         }    #T_d14
