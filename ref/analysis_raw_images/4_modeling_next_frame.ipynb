# %% [markdown]
# # Predicting the next frame of auxilin image

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
from skimage.external.tifffile import imread
from skimage import io
from scipy import ndimage
import os
from os.path import join as oj
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_validate, train_test_split

import data 
X, Y = data.get_data()

# %% [markdown]
# ## Get train and test data, train a linear model

# %%
X_train, Y_train, X_test, Y_test = extract_next_frame_prediction_data(X, Y, window_length=50)

# %%
X_train.shape
# Out:
# (344250, 50)

# %%
m = LinearRegression()
m.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
m.score(X_test, Y_test)
# Out:
# 0.19990901994046262

# %%
plt.plot(m.coef_)

# %% [markdown]
# ### Different window_length

# %%
X_train, Y_train, X_test, Y_test = extract_next_frame_prediction_data(X, Y, window_length=100)
m = LinearRegression()
m.fit(X_train, Y_train)
m.score(X_test, Y_test)
# Out:
# 0.20130428818776283

# %%
X_train, Y_train, X_test, Y_test = extract_next_frame_prediction_data(X, Y, window_length=10)
m = LinearRegression()
m.fit(X_train, Y_train)
m.score(X_test, Y_test)
# Out:
# 0.18035449571355813

# %%
plt.plot(m.coef_)
